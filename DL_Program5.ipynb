# %% [markdown]
# <a href="https://colab.research.google.com/github/snehavyshnavi/Deep-Learning/blob/main/DL_Program5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x=tf.constant([[0,0],[0,1],[1,0],[1,1]],dtype=tf.float32)
y=tf.constant([[0],[1],[1],[0]],dtype=tf.float32)

# %%
model=Sequential([
    Dense(units=4,activation='sigmoid',input_shape=(2,)),
    Dense(units=1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
print("\nModel Summary")
model.summary()
# Out:
# Model Summary
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17 (68.00 B)
#  Trainable params: 17 (68.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\nTraining the model...")
history= model.fit(x, y, epochs=5000, verbose=0)
print("Training Finished")

loss,accuracy= model.evaluate(x,y,verbose=0)
print(f"\nModel Evaluation:")
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Training the model...
# Training Finished
#
# Model Evaluation:
# Loss: 0.0895
# Accuracy: 1.0000

# %%
print("\nPredictions on XOR inputs:")
predictions = model.predict(x)
for i in range(len(x)):
  print(f"Input:{x[i]} , Expected Output: {y[i][0]}, Predicted Output: {predictions[i][0]:.4f} (Rounded: {round(predictions[i][0])})")
# Out:
# Predictions on XOR inputs:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Input:[0. 0.] , Expected Output: 0.0, Predicted Output: 0.0350 (Rounded: 0)
# Input:[0. 1.] , Expected Output: 1.0, Predicted Output: 0.8711 (Rounded: 1)
# Input:[1. 0.] , Expected Output: 1.0, Predicted Output: 0.9648 (Rounded: 1)
# Input:[1. 1.] , Expected Output: 0.0, Predicted Output: 0.1380 (Rounded: 0)
