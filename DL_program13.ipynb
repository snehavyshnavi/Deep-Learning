# %% [markdown]
# <a href="https://colab.research.google.com/github/snehavyshnavi/Deep-Learning/blob/main/DL_program13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import reuters
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dense

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
num_classes=max(train_labels)+1
print(f" Number of classes:{num_classes}")
max_newswire_length = 200
train_data = pad_sequences(train_data, maxlen=max_newswire_length, padding='post', truncating='post')
test_data = pad_sequences(test_data, maxlen=max_newswire_length, padding='post', truncating='post')
train_labels = to_categorical(train_labels, num_classes=num_classes)
test_labels = to_categorical(test_labels, num_classes=num_classes)
# Out:
#  Number of classes:46

# %%
vector_size = 10000
embedding_dim = 128
model = Sequential([
    Embedding(vector_size, embedding_dim, input_length=max_newswire_length),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(train_data, train_labels, epochs=10, batch_size=128

                  , validation_split=0.2,)
loss = accuracy = model.evaluate(test_data, test_labels)
print(f"Accuracy: {loss[1]:.4f},Loss: {loss[0]:.4f},")
# Out:
# Epoch 1/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.3483 - loss: 3.0997 - val_accuracy: 0.3695 - val_loss: 2.2675
# Epoch 2/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.4067 - loss: 2.1974 - val_accuracy: 0.4864 - val_loss: 1.9754
# Epoch 3/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4932 - loss: 1.9613 - val_accuracy: 0.5437 - val_loss: 1.7937
# Epoch 4/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5726 - loss: 1.7217 - val_accuracy: 0.6188 - val_loss: 1.6096
# Epoch 5/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6335 - loss: 1.5758 - val_accuracy: 0.6400 - val_loss: 1.4858
# Epoch 6/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6656 - loss: 1.4159 - val_accuracy: 0.6873 - val_loss: 1.3578
# Epoch 7/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6913 - loss: 1.2874 - val_accuracy: 0.7023 - val_loss: 1.2858
# Epoch 8/10
# ...
